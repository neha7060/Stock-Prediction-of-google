# %% [markdown]
# # Bharat Intern

# %% [markdown]
# # Intern Name - Neha

# %% [markdown]
# # About Dataset

# %% [markdown]
# ## Google Stock Prediction

# %% [markdown]
# This dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.

# %% [markdown]
# ## Importing libraries and data to be used

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('GOOG.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ## Gathering Insights

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# ## There are no null  values in the Dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# # Data Pre-Processing

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ## Creating LSTM Model

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 12s 94ms/step - loss: 0.0044 - mean_absolute_error: 0.0497 - val_loss: 0.0139 - val_mean_absolute_error: 0.0929
# Epoch 2/100
# 28/28 [==============================] - 1s 51ms/step - loss: 6.5654e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0081 - val_mean_absolute_error: 0.0723
# Epoch 3/100
# 28/28 [==============================] - 1s 51ms/step - loss: 4.3942e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0040 - val_mean_absolute_error: 0.0480
# Epoch 4/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.2851e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0061 - val_mean_absolute_error: 0.0618
# Epoch 5/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.2300e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0050 - val_mean_absolute_error: 0.0546
# Epoch 6/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.9981e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0053 - val_mean_absolute_error: 0.0573
# Epoch 7/100
# 28/28 [==============================] - 2s 60ms/step - loss: 4.1162e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0062 - val_mean_absolute_error: 0.0632
# Epoch 8/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.0301e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0040 - val_mean_absolute_error: 0.0490
# Epoch 9/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.7288e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0035 - val_mean_absolute_error: 0.0451
# Epoch 10/100
# 28/28 [==============================] - 2s 58ms/step - loss: 4.0806e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0051 - val_mean_absolute_error: 0.0575
# Epoch 11/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.5918e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0044 - val_mean_absolute_error: 0.0531
# Epoch 12/100
# 28/28 [==============================] - 1s 51ms/step - loss: 3.2926e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0053 - val_mean_absolute_error: 0.0592
# Epoch 13/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.2934e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0034 - val_mean_absolute_error: 0.0450
# Epoch 14/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.0606e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0042 - val_mean_absolute_error: 0.0514
# Epoch 15/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.0717e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0036 - val_mean_absolute_error: 0.0466
# Epoch 16/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.2561e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0059 - val_mean_absolute_error: 0.0619
# Epoch 17/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.8213e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0031 - val_mean_absolute_error: 0.0418
# Epoch 18/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.6842e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0036 - val_mean_absolute_error: 0.0446
# Epoch 19/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.0617e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0033 - val_mean_absolute_error: 0.0438
# Epoch 20/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.7941e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0037 - val_mean_absolute_error: 0.0469
# Epoch 21/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.7776e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0052 - val_mean_absolute_error: 0.0577
# Epoch 22/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.5831e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0507
# Epoch 23/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.6152e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0022 - val_mean_absolute_error: 0.0337
# Epoch 24/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.8158e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0059 - val_mean_absolute_error: 0.0611
# Epoch 25/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.4420e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0041 - val_mean_absolute_error: 0.0481
# Epoch 26/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.6803e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0045 - val_mean_absolute_error: 0.0525
# Epoch 27/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.0679e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0023 - val_mean_absolute_error: 0.0345
# Epoch 28/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.7523e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0028 - val_mean_absolute_error: 0.0391
# Epoch 29/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.5011e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 30/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.2668e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0035 - val_mean_absolute_error: 0.0453
# Epoch 31/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.3508e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0037 - val_mean_absolute_error: 0.0469
# Epoch 32/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.2923e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 33/100
# 28/28 [==============================] - 1s 49ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0037 - val_mean_absolute_error: 0.0472
# Epoch 34/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.0975e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0023 - val_mean_absolute_error: 0.0355
# Epoch 35/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.9784e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0034 - val_mean_absolute_error: 0.0447
# Epoch 36/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.9603e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0025 - val_mean_absolute_error: 0.0371
# Epoch 37/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1733e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0046 - val_mean_absolute_error: 0.0535
# Epoch 38/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.0963e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0038 - val_mean_absolute_error: 0.0471
# Epoch 39/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.1345e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0044 - val_mean_absolute_error: 0.0513
# Epoch 40/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.9910e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0022 - val_mean_absolute_error: 0.0342
# Epoch 41/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8629e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 42/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.9148e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 43/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.7056e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 44/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7575e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0021 - val_mean_absolute_error: 0.0344
# Epoch 45/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7243e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0020 - val_mean_absolute_error: 0.0332
# Epoch 46/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.6217e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 47/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7602e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0028 - val_mean_absolute_error: 0.0436
# Epoch 48/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8597e-04 - mean_absolute_error: 0.0100 - val_loss: 9.0741e-04 - val_mean_absolute_error: 0.0223
# Epoch 49/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.7529e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0020 - val_mean_absolute_error: 0.0348
# Epoch 50/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5025e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301
# Epoch 51/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7078e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275
# Epoch 52/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.6152e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 53/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.4489e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 54/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.5494e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0020 - val_mean_absolute_error: 0.0360
# Epoch 55/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4306e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 56/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4494e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374
# Epoch 57/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4991e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 58/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2316e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0023 - val_mean_absolute_error: 0.0384
# Epoch 59/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2827e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 60/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2941e-04 - mean_absolute_error: 0.0082 - val_loss: 8.4390e-04 - val_mean_absolute_error: 0.0213
# Epoch 61/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2901e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0028 - val_mean_absolute_error: 0.0440
# Epoch 62/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4772e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0040 - val_mean_absolute_error: 0.0535
# Epoch 63/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.5151e-04 - mean_absolute_error: 0.0088 - val_loss: 8.1562e-04 - val_mean_absolute_error: 0.0218
# Epoch 64/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.2165e-04 - mean_absolute_error: 0.0079 - val_loss: 7.5828e-04 - val_mean_absolute_error: 0.0203
# Epoch 65/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.1864e-04 - mean_absolute_error: 0.0079 - val_loss: 7.8521e-04 - val_mean_absolute_error: 0.0208
# Epoch 66/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2038e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 67/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.2314e-04 - mean_absolute_error: 0.0080 - val_loss: 9.6471e-04 - val_mean_absolute_error: 0.0238
# Epoch 68/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.1240e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 69/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1744e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 70/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.2419e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 71/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0930e-04 - mean_absolute_error: 0.0074 - val_loss: 4.2468e-04 - val_mean_absolute_error: 0.0151
# Epoch 72/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.2551e-04 - mean_absolute_error: 0.0081 - val_loss: 9.0983e-04 - val_mean_absolute_error: 0.0243
# Epoch 73/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2124e-04 - mean_absolute_error: 0.0078 - val_loss: 5.3726e-04 - val_mean_absolute_error: 0.0174
# Epoch 74/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.0312e-04 - mean_absolute_error: 0.0072 - val_loss: 5.9465e-04 - val_mean_absolute_error: 0.0181
# Epoch 75/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0838e-04 - mean_absolute_error: 0.0074 - val_loss: 8.6197e-04 - val_mean_absolute_error: 0.0232
# Epoch 76/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.0006e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6400e-04 - val_mean_absolute_error: 0.0142
# Epoch 77/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.0049e-04 - mean_absolute_error: 0.0070 - val_loss: 4.5665e-04 - val_mean_absolute_error: 0.0160
# Epoch 78/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.0953e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 79/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.1540e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0242e-04 - val_mean_absolute_error: 0.0130
# Epoch 80/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.1235e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 81/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.0870e-04 - mean_absolute_error: 0.0074 - val_loss: 3.3654e-04 - val_mean_absolute_error: 0.0136
# Epoch 82/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0385e-04 - mean_absolute_error: 0.0070 - val_loss: 5.5652e-04 - val_mean_absolute_error: 0.0171
# Epoch 83/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.1629e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 84/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 85/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.0262e-04 - mean_absolute_error: 0.0073 - val_loss: 7.4935e-04 - val_mean_absolute_error: 0.0204
# Epoch 86/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0598e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1025e-04 - val_mean_absolute_error: 0.0132
# Epoch 87/100
# 28/28 [==============================] - 2s 57ms/step - loss: 9.9189e-05 - mean_absolute_error: 0.0069 - val_loss: 4.3844e-04 - val_mean_absolute_error: 0.0157
# Epoch 88/100
# 28/28 [==============================] - 2s 58ms/step - loss: 9.0498e-05 - mean_absolute_error: 0.0066 - val_loss: 6.4720e-04 - val_mean_absolute_error: 0.0194
# Epoch 89/100
# 28/28 [==============================] - 2s 58ms/step - loss: 8.9350e-05 - mean_absolute_error: 0.0066 - val_loss: 3.2291e-04 - val_mean_absolute_error: 0.0133
# Epoch 90/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.0192e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8753e-04 - val_mean_absolute_error: 0.0127
# Epoch 91/100
# 28/28 [==============================] - 2s 60ms/step - loss: 9.3197e-05 - mean_absolute_error: 0.0068 - val_loss: 6.3434e-04 - val_mean_absolute_error: 0.0199
# Epoch 92/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0232e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 93/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.0846e-04 - mean_absolute_error: 0.0072 - val_loss: 5.1682e-04 - val_mean_absolute_error: 0.0174
# Epoch 94/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2276e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 95/100
# 28/28 [==============================] - 2s 59ms/step - loss: 9.7485e-05 - mean_absolute_error: 0.0071 - val_loss: 5.9177e-04 - val_mean_absolute_error: 0.0186
# Epoch 96/100
# 28/28 [==============================] - 2s 58ms/step - loss: 9.4643e-05 - mean_absolute_error: 0.0070 - val_loss: 3.3973e-04 - val_mean_absolute_error: 0.0137
# Epoch 97/100
# 28/28 [==============================] - 2s 60ms/step - loss: 9.9801e-05 - mean_absolute_error: 0.0068 - val_loss: 5.7153e-04 - val_mean_absolute_error: 0.0177
# Epoch 98/100
# 28/28 [==============================] - 2s 59ms/step - loss: 9.8905e-05 - mean_absolute_error: 0.0071 - val_loss: 6.3378e-04 - val_mean_absolute_error: 0.0191
# Epoch 99/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.0213e-04 - mean_absolute_error: 0.0070 - val_loss: 6.9694e-04 - val_mean_absolute_error: 0.0201
# Epoch 100/100
# 28/28 [==============================] - 2s 58ms/step - loss: 8.6920e-05 - mean_absolute_error: 0.0066 - val_loss: 6.1775e-04 - val_mean_absolute_error: 0.0180

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 0s 20ms/step
# array([[0.4046893 , 0.4063512 ],
#        [0.40363795, 0.4050818 ],
#        [0.4013794 , 0.40287447],
#        [0.4086694 , 0.41045597],
#        [0.411604  , 0.41341168]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1421.2616, 1421.367 ],
#        [1419.3125, 1419.0144],
#        [1415.1254, 1414.9235],
#        [1428.6404, 1428.9745],
#        [1434.0809, 1434.4524]], dtype=float32)

# %% [markdown]
# ## Visualizing Actual Vs Predicted Data

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1421.261597      1421.366943
# 2020-05-28  1396.86  1416.73     1419.312500      1419.014404
# 2020-05-29  1416.94  1428.92     1415.125366      1414.923462
# 2020-06-01  1418.39  1431.82     1428.640381      1428.974487
# 2020-06-02  1430.55  1439.22     1434.080933      1434.452393

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## Predicting Upcoming 10 Days

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2382.155762      2419.518311
# 2021-06-10  2494.01  2521.60     2388.187500      2426.287109
# 2021-06-11  2524.92  2513.93     2415.951172      2454.921875
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# # Thank You
